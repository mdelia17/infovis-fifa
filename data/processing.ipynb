# %%
import pandas as pd
import json
pd.set_option("display.max_columns", 106)
pd.set_option("display.max_rows", 20)
pd.set_option('display.float_format','{:.1f}'.format)

# %%
df = pd.read_csv("dataset.csv")

# %%
df
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2         200389  https://sofifa.com/player/200389/jan-oblak/210002
# 3         188545  https://sofifa.com/player/188545/robert-lewand...
# 4         190871  https://sofifa.com/player/190871/neymar-da-sil...
# ...          ...                                                ...
# 18939     256679  https://sofifa.com/player/256679/kevin-angulo/...
# 18940     257710  https://sofifa.com/player/257710/mengxuan-zhan...
# 18941     250989  https://sofifa.com/player/250989/zhenghao-wang...
# 18942     257697  https://sofifa.com/player/257697/zitong-chen/2...
# 18943     257936   https://sofifa.com/player/257936/yue-song/210002
#
#               short_name                            long_name  age  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   33
# ...

# %% [markdown]
# # Dataset giocatori

# %%
df = df.loc[(df['league_name'] == "Italian Serie A") | 
                (df['league_name'] == "English Premier League") |
                (df['league_name'] == "German 1. Bundesliga") | 
                (df['league_name'] == "Spain Primera Division") |
                (df['league_name'] == "French Ligue 1")]

# %%
df
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2         200389  https://sofifa.com/player/200389/jan-oblak/210002
# 3         188545  https://sofifa.com/player/188545/robert-lewand...
# 4         190871  https://sofifa.com/player/190871/neymar-da-sil...
# ...          ...                                                ...
# 18670     253041  https://sofifa.com/player/253041/jean-lambert-...
# 18757     251674  https://sofifa.com/player/251674/jean-belehoua...
# 18786     252450  https://sofifa.com/player/252450/harry-boyes/2...
# 18836     252466  https://sofifa.com/player/252466/devid-eugene-...
# 18848     258918  https://sofifa.com/player/258918/gian-marco-cr...
#
#               short_name                            long_name  age  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   33
# ...

# %%
columns = ["sofifa_id", "short_name", "age", "height_cm", "weight_kg", "club_name", "league_name", "value_eur", "player_positions","overall"
          ,"pace", "shooting", "passing", "dribbling", "defending", "physic"
          ,"attacking_crossing", "attacking_finishing", "attacking_heading_accuracy", "attacking_short_passing", "attacking_volleys"
          ,"skill_dribbling", "skill_curve", "skill_fk_accuracy", "skill_long_passing", "skill_ball_control"
          ,"movement_acceleration", "movement_sprint_speed", "movement_agility", "movement_reactions", "movement_balance"
          ,"power_shot_power", "power_jumping", "power_stamina", "power_strength", "power_long_shots"
          ,"mentality_aggression", "mentality_interceptions", "mentality_positioning", "mentality_vision", "mentality_penalties", "mentality_composure"
          ,"defending_standing_tackle", "defending_sliding_tackle"
          ,"goalkeeping_diving", "goalkeeping_handling", "goalkeeping_kicking", "goalkeeping_positioning", "goalkeeping_reflexes"
          ]

# %%
df = df[columns]
df
# Out:
#        sofifa_id         short_name  age  height_cm  weight_kg  \
# 0         158023           L. Messi   33        170         72
# 1          20801  Cristiano Ronaldo   35        187         83
# 2         200389           J. Oblak   27        188         87
# 3         188545     R. Lewandowski   31        184         80
# 4         190871          Neymar Jr   28        175         68
# ...          ...                ...  ...        ...        ...
# 18670     253041    J. Evan's Allan   21        180         70
# 18757     251674       J. Belehouan   19        190         76
# 18786     252450           H. Boyes   22        178         73
# 18836     252466           D. Bouah   18        177         74
# 18848     258918          G. Crespi   19        188         75
#
#                  club_name             league_name  value_eur  \
# 0             FC Barcelona  Spain Primera Division   67500000
# 1                 Juventus         Italian Serie A   46000000
# ...

# %%
df["player_positions"] = df["player_positions"].apply(lambda x: x.replace("RWB", "RB"))
df["player_positions"] = df["player_positions"].apply(lambda x: x.replace("LWB", "LB"))
df["player_positions"] = df["player_positions"].apply(lambda x: x.replace("RW", "RM"))
df["player_positions"] = df["player_positions"].apply(lambda x: x.replace("LW", "LM"))
df["player_positions"] = df["player_positions"].apply(lambda x: x.replace("CDM", "CM"))
df["player_positions"] = df["player_positions"].apply(lambda x: x.replace("CAM", "CM"))
df["player_positions"] = df["player_positions"].apply(lambda x: x.replace("CF", "ST"))

df["player_positions"] = df["player_positions"].apply(lambda x: x.replace("GK", "Portiere"))
df["player_positions"] = df["player_positions"].apply(lambda x: x.replace("RB", "Terzino Dx"))
df["player_positions"] = df["player_positions"].apply(lambda x: x.replace("LB", "Terzino Sx"))
df["player_positions"] = df["player_positions"].apply(lambda x: x.replace("CM", "Centrocampista"))
df["player_positions"] = df["player_positions"].apply(lambda x: x.replace("LM", "Esterno Sx"))
df["player_positions"] = df["player_positions"].apply(lambda x: x.replace("RM", "Esterno Dx"))
df["player_positions"] = df["player_positions"].apply(lambda x: x.replace("ST", "Attaccante"))
df["player_positions"] = df["player_positions"].apply(lambda x: x.replace("CB", "Difensore"))
# Out:
# <ipython-input-8-18f9b5acce1a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["player_positions"] = df["player_positions"].apply(lambda x: x.replace("RWB", "RB"))
# <ipython-input-8-18f9b5acce1a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["player_positions"] = df["player_positions"].apply(lambda x: x.replace("LWB", "LB"))
# <ipython-input-8-18f9b5acce1a>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df
# Out:
#        sofifa_id         short_name  age  height_cm  weight_kg  \
# 0         158023           L. Messi   33        170         72
# 1          20801  Cristiano Ronaldo   35        187         83
# 2         200389           J. Oblak   27        188         87
# 3         188545     R. Lewandowski   31        184         80
# 4         190871          Neymar Jr   28        175         68
# ...          ...                ...  ...        ...        ...
# 18670     253041    J. Evan's Allan   21        180         70
# 18757     251674       J. Belehouan   19        190         76
# 18786     252450           H. Boyes   22        178         73
# 18836     252466           D. Bouah   18        177         74
# 18848     258918          G. Crespi   19        188         75
#
#                  club_name             league_name  value_eur  \
# 0             FC Barcelona  Spain Primera Division   67500000
# 1                 Juventus         Italian Serie A   46000000
# ...

# %%
df["player_positions"] = df["player_positions"].apply(lambda x: x.replace(", ", ","))
# Out:
# <ipython-input-10-550fced067a0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["player_positions"] = df["player_positions"].apply(lambda x: x.replace(", ", ","))

# %%
df
# Out:
#        sofifa_id         short_name  age  height_cm  weight_kg  \
# 0         158023           L. Messi   33        170         72
# 1          20801  Cristiano Ronaldo   35        187         83
# 2         200389           J. Oblak   27        188         87
# 3         188545     R. Lewandowski   31        184         80
# 4         190871          Neymar Jr   28        175         68
# ...          ...                ...  ...        ...        ...
# 18670     253041    J. Evan's Allan   21        180         70
# 18757     251674       J. Belehouan   19        190         76
# 18786     252450           H. Boyes   22        178         73
# 18836     252466           D. Bouah   18        177         74
# 18848     258918          G. Crespi   19        188         75
#
#                  club_name             league_name  value_eur  \
# 0             FC Barcelona  Spain Primera Division   67500000
# 1                 Juventus         Italian Serie A   46000000
# ...

# %%
df['player_positions'] = df['player_positions'].str.strip('').str.split(',')
# Out:
# <ipython-input-12-6bc923aaba80>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['player_positions'] = df['player_positions'].str.strip('').str.split(',')

# %%
df
# Out:
#        sofifa_id         short_name  age  height_cm  weight_kg  \
# 0         158023           L. Messi   33        170         72
# 1          20801  Cristiano Ronaldo   35        187         83
# 2         200389           J. Oblak   27        188         87
# 3         188545     R. Lewandowski   31        184         80
# 4         190871          Neymar Jr   28        175         68
# ...          ...                ...  ...        ...        ...
# 18670     253041    J. Evan's Allan   21        180         70
# 18757     251674       J. Belehouan   19        190         76
# 18786     252450           H. Boyes   22        178         73
# 18836     252466           D. Bouah   18        177         74
# 18848     258918          G. Crespi   19        188         75
#
#                  club_name             league_name  value_eur  \
# 0             FC Barcelona  Spain Primera Division   67500000
# 1                 Juventus         Italian Serie A   46000000
# ...

# %%
df['player_positions'] = df['player_positions'].apply(set)
# Out:
# <ipython-input-14-d72184d871d2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['player_positions'] = df['player_positions'].apply(set)

# %%
df
# Out:
#        sofifa_id         short_name  age  height_cm  weight_kg  \
# 0         158023           L. Messi   33        170         72
# 1          20801  Cristiano Ronaldo   35        187         83
# 2         200389           J. Oblak   27        188         87
# 3         188545     R. Lewandowski   31        184         80
# 4         190871          Neymar Jr   28        175         68
# ...          ...                ...  ...        ...        ...
# 18670     253041    J. Evan's Allan   21        180         70
# 18757     251674       J. Belehouan   19        190         76
# 18786     252450           H. Boyes   22        178         73
# 18836     252466           D. Bouah   18        177         74
# 18848     258918          G. Crespi   19        188         75
#
#                  club_name             league_name  value_eur  \
# 0             FC Barcelona  Spain Primera Division   67500000
# 1                 Juventus         Italian Serie A   46000000
# ...

# %%
df['player_positions'] = [', '.join(map(str, l)) for l in df['player_positions']]
# Out:
# <ipython-input-16-da4a7cdb8b68>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['player_positions'] = [', '.join(map(str, l)) for l in df['player_positions']]

# %%
df
# Out:
#        sofifa_id         short_name  age  height_cm  weight_kg  \
# 0         158023           L. Messi   33        170         72
# 1          20801  Cristiano Ronaldo   35        187         83
# 2         200389           J. Oblak   27        188         87
# 3         188545     R. Lewandowski   31        184         80
# 4         190871          Neymar Jr   28        175         68
# ...          ...                ...  ...        ...        ...
# 18670     253041    J. Evan's Allan   21        180         70
# 18757     251674       J. Belehouan   19        190         76
# 18786     252450           H. Boyes   22        178         73
# 18836     252466           D. Bouah   18        177         74
# 18848     258918          G. Crespi   19        188         75
#
#                  club_name             league_name  value_eur  \
# 0             FC Barcelona  Spain Primera Division   67500000
# 1                 Juventus         Italian Serie A   46000000
# ...

# %%
df.rename(columns={'pace': 'movement_pace', 'shooting': 'attacking_shooting', 'dribbling': 'skill_dribbling',
                  'passing': 'skill_passing', 'defending': 'defending_defending', 'physic': 'power_physic'})
# Out:
#        sofifa_id         short_name  age  height_cm  weight_kg  \
# 0         158023           L. Messi   33        170         72
# 1          20801  Cristiano Ronaldo   35        187         83
# 2         200389           J. Oblak   27        188         87
# 3         188545     R. Lewandowski   31        184         80
# 4         190871          Neymar Jr   28        175         68
# ...          ...                ...  ...        ...        ...
# 18670     253041    J. Evan's Allan   21        180         70
# 18757     251674       J. Belehouan   19        190         76
# 18786     252450           H. Boyes   22        178         73
# 18836     252466           D. Bouah   18        177         74
# 18848     258918          G. Crespi   19        188         75
#
#                  club_name             league_name  value_eur  \
# 0             FC Barcelona  Spain Primera Division   67500000
# 1                 Juventus         Italian Serie A   46000000
# ...

# %%
gk = df.loc[(df['player_positions'] == "Portiere")]
players = df.loc[(df['player_positions'] != "Portiere")]

# %%
players
# Out:
#        sofifa_id         short_name  age  height_cm  weight_kg  \
# 0         158023           L. Messi   33        170         72
# 1          20801  Cristiano Ronaldo   35        187         83
# 3         188545     R. Lewandowski   31        184         80
# 4         190871          Neymar Jr   28        175         68
# 5         192985       K. De Bruyne   29        181         70
# ...          ...                ...  ...        ...        ...
# 18607     243890            C. Rowe   20        180         70
# 18670     253041    J. Evan's Allan   21        180         70
# 18757     251674       J. Belehouan   19        190         76
# 18786     252450           H. Boyes   22        178         73
# 18836     252466           D. Bouah   18        177         74
#
#                  club_name             league_name  value_eur  \
# 0             FC Barcelona  Spain Primera Division   67500000
# 1                 Juventus         Italian Serie A   46000000
# ...

# %%
gk['punti_portiere'] = gk.iloc[:, [43,44,45,46,47]].mean(axis=1)
gk['punti_difesa'] = gk.iloc[:, [41,42]].mean(axis=1)
gk['punti_attacco'] = gk.iloc[:, [15,16,17,18,19]].mean(axis=1)
gk['punti_tecnica'] = gk.iloc[:, [20,21,22,23,24]].mean(axis=1)
gk['punti_potenza'] = gk.iloc[:, [30,31,32,33,34]].mean(axis=1)
gk['punti_velocita'] = gk.iloc[:, [25,26,27,28,29]].mean(axis=1)
gk['punti_mentalita'] = gk.iloc[:, [35,36,37,38,39,40]].mean(axis=1)
# Out:
# <ipython-input-21-330acc8c0128>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gk['punti_portiere'] = gk.iloc[:, [43,44,45,46,47]].mean(axis=1)
# <ipython-input-21-330acc8c0128>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gk['punti_difesa'] = gk.iloc[:, [41,42]].mean(axis=1)
# <ipython-input-21-330acc8c0128>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
players['punti_portiere'] = players.iloc[:, [43,44,45,46,47]].mean(axis=1)
players['punti_difesa'] = players.iloc[:, [13,41,42]].mean(axis=1)
players['punti_attacco'] = players.iloc[:, [10,15,16,17,18,19]].mean(axis=1)
players['punti_tecnica'] = players.iloc[:, [11,12,20,21,22,23,24]].mean(axis=1)
players['punti_potenza'] = players.iloc[:, [14,30,31,32,33,34]].mean(axis=1)
players['punti_velocita'] = players.iloc[:, [9,25,26,27,28,29]].mean(axis=1)
players['punti_mentalita'] = players.iloc[:, [35,36,37,38,39,40]].mean(axis=1)
# Out:
# <ipython-input-22-bf58f08044c1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   players['punti_portiere'] = players.iloc[:, [43,44,45,46,47]].mean(axis=1)
# <ipython-input-22-bf58f08044c1>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   players['punti_difesa'] = players.iloc[:, [13,41,42]].mean(axis=1)
# <ipython-input-22-bf58f08044c1>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
# ...

# %%
columns2 = ["sofifa_id", "short_name", "age", "height_cm", "weight_kg", "club_name", "league_name", "value_eur", "player_positions"
           ,"overall","punti_portiere", "punti_difesa", "punti_attacco", "punti_tecnica", "punti_potenza", "punti_velocita"
           ,"punti_mentalita"]

# %%
gk = gk[columns2]
players = players[columns2]

# %%
df = gk.append(players)

# %%
df
# Out:
#        sofifa_id       short_name  age  height_cm  weight_kg  \
# 2         200389         J. Oblak   27        188         87
# 7         192448    M. ter Stegen   28        187         85
# 9         212831          Alisson   27        191         91
# 12        192119      T. Courtois   28        199         96
# 16        167495         M. Neuer   34        193         92
# ...          ...              ...  ...        ...        ...
# 18607     243890          C. Rowe   20        180         70
# 18670     253041  J. Evan's Allan   21        180         70
# 18757     251674     J. Belehouan   19        190         76
# 18786     252450         H. Boyes   22        178         73
# 18836     252466         D. Bouah   18        177         74
#
#                club_name             league_name  value_eur player_positions  \
# 2        Atlético Madrid  Spain Primera Division   75000000         Portiere
# ...

# %%
df = df.sort_values(by=['league_name', 'club_name', 'player_positions'])

# %%
cols_float = ["punti_portiere", "punti_difesa", "punti_attacco", "punti_tecnica", "punti_potenza", "punti_velocita"
           ,"punti_mentalita","overall"]

# %%
df[cols_float] = df[cols_float].round(decimals=1)

# %%
df["club_name"] = df["club_name"].apply(lambda x: x.replace(u"\u00c9", "e"))
df["club_name"] = df["club_name"].apply(lambda x: x.replace(u"\u00ee", "i"))
df["club_name"] = df["club_name"].apply(lambda x: x.replace(u"\u00f6", "o"))
df["club_name"] = df["club_name"].apply(lambda x: x.replace(u"\u00fc", "u"))
df["club_name"] = df["club_name"].apply(lambda x: x.replace(u"\u00e1", "a"))
df["club_name"] = df["club_name"].apply(lambda x: x.replace(u"\u00e9", "e"))

df["short_name"] = df["short_name"].apply(lambda x: x.replace(u"\u00f1", "n"))
df["short_name"] = df["short_name"].apply(lambda x: x.replace(u"\u00e1", "a"))
df["short_name"] = df["short_name"].apply(lambda x: x.replace(u"\u00e9", "e"))
df["short_name"] = df["short_name"].apply(lambda x: x.replace(u"\u00f6", "o"))
df["short_name"] = df["short_name"].apply(lambda x: x.replace(u"\u00f3", "o"))
df["short_name"] = df["short_name"].apply(lambda x: x.replace(u"\u00fa", "u"))
df["short_name"] = df["short_name"].apply(lambda x: x.replace(u"\u00c1", "A"))
df["short_name"] = df["short_name"].apply(lambda x: x.replace(u"\u00e0", "a"))
df["short_name"] = df["short_name"].apply(lambda x: x.replace(u"\u00e7", "c"))
df["short_name"] = df["short_name"].apply(lambda x: x.replace(u"\u00ed", "i"))
df["short_name"] = df["short_name"].apply(lambda x: x.replace(u"\u00d3", "O"))
df["short_name"] = df["short_name"].apply(lambda x: x.replace(u"\u00d6", "O"))
df["short_name"] = df["short_name"].apply(lambda x: x.replace(u"\u00df", "s"))
df["short_name"] = df["short_name"].apply(lambda x: x.replace(u"\u00f0", "d"))
df["short_name"] = df["short_name"].apply(lambda x: x.replace(u"\u00fc", "u"))
df["short_name"] = df["short_name"].apply(lambda x: x.replace(u"\u00e3", "a"))
df["short_name"] = df["short_name"].apply(lambda x: x.replace(u"\u00dc", "U"))
df["short_name"] = df["short_name"].apply(lambda x: x.replace(u"\u00ef", "i"))
df["short_name"] = df["short_name"].apply(lambda x: x.replace(u"\u00f8", "o"))
df["short_name"] = df["short_name"].apply(lambda x: x.replace(u"\u00e4", "a"))
df["short_name"] = df["short_name"].apply(lambda x: x.replace(u"\u00c7", "a"))
df["short_name"] = df["short_name"].apply(lambda x: x.replace(u"\u00c9", "e"))
df["short_name"] = df["short_name"].apply(lambda x: x.replace(u"\u00d8", "O"))
df["short_name"] = df["short_name"].apply(lambda x: x.replace(u"\u00e2", "a"))
df["short_name"] = df["short_name"].apply(lambda x: x.replace(u"\u00eb", "e"))
df["short_name"] = df["short_name"].apply(lambda x: x.replace(u"\u00fd", "y"))
df["short_name"] = df["short_name"].apply(lambda x: x.replace(u"\u00ea", "e"))
df["short_name"] = df["short_name"].apply(lambda x: x.replace(u"\u00e8", "e"))
df["short_name"] = df["short_name"].apply(lambda x: x.replace(u"\u00f2", "o"))
df["short_name"] = df["short_name"].apply(lambda x: x.replace(u"\u00e6", "ae"))

# %%
df
# Out:
#        sofifa_id          short_name  age  height_cm  weight_kg  \
# 192       193301        A. Lacazette   29        176         77
# 3818      236988          E. Nketiah   21        175         72
# 14703     247463          F. Balogun   18        179         70
# 41        188567       P. Aubameyang   31        187         80
# 2051      251566  Gabriel Martinelli   19        180         69
# ...          ...                 ...  ...        ...        ...
# 486       211241          Ruben Pena   28        170         65
# 515       237942        P. Estupinan   22        175         73
# 639       193171         Jaume Costa   32        171         62
# 1130      205566      Alberto Moreno   27        171         65
# 1612      228302             Pedraza   24        184         73
#
#            club_name             league_name  value_eur  \
# 192          Arsenal  English Premier League   26000000
# 3818         Arsenal  English Premier League    4300000
# ...

# %%
df.to_json(orient="records",path_or_buf="players.json", indent=4)
# parsed = json.loads(result)
# json.dumps(parsed, indent=4)

# %% [markdown]
# ## Dataset squadre

# %%
teams = df

# %%
teams
# Out:
#        sofifa_id          short_name  age  height_cm  weight_kg  \
# 192       193301        A. Lacazette   29        176         77
# 3818      236988          E. Nketiah   21        175         72
# 14703     247463          F. Balogun   18        179         70
# 41        188567       P. Aubameyang   31        187         80
# 2051      251566  Gabriel Martinelli   19        180         69
# ...          ...                 ...  ...        ...        ...
# 486       211241          Ruben Pena   28        170         65
# 515       237942        P. Estupinan   22        175         73
# 639       193171         Jaume Costa   32        171         62
# 1130      205566      Alberto Moreno   27        171         65
# 1612      228302             Pedraza   24        184         73
#
#            club_name             league_name  value_eur  \
# 192          Arsenal  English Premier League   26000000
# 3818         Arsenal  English Premier League    4300000
# ...

# %%
a = teams.groupby(['club_name','league_name']).agg({'club_name':'count','punti_portiere' : 'mean','punti_attacco' : 'mean'
                                  ,'punti_difesa' : 'mean','punti_tecnica' : 'mean'
                                  ,'punti_velocita' : 'mean','punti_mentalita' : 'mean'
                                  ,'punti_potenza' : 'mean','overall' : 'mean'})
a = a.rename(columns={'club_name':'count'})

# %%
a.columns
# Out:
# Index(['count', 'punti_portiere', 'punti_attacco', 'punti_difesa',
#        'punti_tecnica', 'punti_velocita', 'punti_mentalita', 'punti_potenza',
#        'overall'],
#       dtype='object')

# %%
a = a.reset_index()
a = a.sort_values(by=['league_name', 'club_name'])
a_cols_float = ['punti_portiere','punti_attacco','punti_difesa','punti_tecnica','punti_velocita','punti_mentalita',
               'punti_potenza','overall']
a[cols_float] = a[cols_float].round(decimals=1)
a = a.reset_index()
a = a.drop(['index'],axis=1)

# %%
a_cols = ['club_name','league_name','count','punti_portiere','punti_attacco','punti_difesa','punti_tecnica','punti_velocita','punti_mentalita',
               'punti_potenza','overall']
a = a[a_cols]

# %%
a
# Out:
#                  club_name             league_name  count  punti_portiere  \
# 0                  Arsenal  English Premier League     33            23.4
# 1              Aston Villa  English Premier League     33            25.6
# 2   Brighton & Hove Albion  English Premier League     33            24.0
# 3                  Burnley  English Premier League     30            23.4
# 4                  Chelsea  English Premier League     33            23.4
# ..                     ...                     ...    ...             ...
# 93                SD Eibar  Spain Primera Division     30            23.4
# 94               SD Huesca  Spain Primera Division     30            22.1
# 95              Sevilla FC  Spain Primera Division     33            25.0
# 96             Valencia CF  Spain Primera Division     33            22.9
# 97           Villarreal CF  Spain Primera Division     32            23.6
#
#     punti_attacco  punti_difesa  punti_tecnica  punti_velocita  \
# ...

# %%
a.to_json(orient="records",path_or_buf="teams.json", indent=4)
